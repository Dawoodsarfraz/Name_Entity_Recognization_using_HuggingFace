# %%
# Dawood Sarfraz

# %%
# Name Entity Recognization

# %% [markdown]
# | Tokens     | Tags |
# | ---------  | -------- |
# | Dawood     | B-PER    |
# | Sarfraz    | I-PER    |
# | Studied    | 0        |
# | Computer   | 0        |
# | Science    | 0        |
# | at         | 0        |
# | FAST NUCES | B-ORG    |
# | Pakistan   | B-LOC    |

# %% [markdown]
# ![image.png](attachment:d7274f8e-35e6-40b7-adbc-b8f759759fb5.png)
# #### Fig2 Pic from Google

# %% [markdown]
# ![image.png](attachment:0bbabaeb-f9aa-4f8b-a2f2-9d80cea4c0fa.png)
